# %% [markdown]
# > 1단계

# %% [markdown]
# <database>
# 1. [개념] 테이블 구조 변경 명령어의 종류를 기본 에제를 통해 설명하세요.
# 구조 변경 명령어 alter table의 종류에는 add, modift, drop, rename이 있다.
# EX)
# ALTER TABLE EMP ADD EMAIL VARCHAR2(100);
# ALTER TABLE EMP MODIFY ENAME VARCHAR2(50);
# ALTER TABLE EMP DROP COLUMN COMM;
# ALTER TABLE EMP RENAME COLUMN ENAME TO EMP_NAME;
#
# 2. [실습]
#  CREATE TABLE COURSES (
#        COURSE_ID NUMBER(5) PRIMARY KEY,
#        TITLE VARCHAR2(100) NOT NULL,
#        INSTRUCTOR VARCHAR2(50),
#        PRICE NUMBER(8,0),
#        OPEN_DATE DATE
#    );
#     테이블 생성
#     1) 에(ADD) - 열 추가하기
#     강좌의 난이도('초급', '중급', '고급')를 저장하기 위해 DIFFICULTY 열 (타입: VARCHAR2(20))을 추가하세요.
#     수강생들의 평점과 리뷰 수를 기록할 RATING_SCORE (타입: NUMBER(3,1))와 RATING_COUNT (타입: NUMBER) 열 두 개를 한 번에 추가하세요.
#     2)모(MODIFY) - 열 속성 수정하기
#     강좌 제목(TITLE)이 100자로는 부족한 경우가 있어, 최대 200자까지 저장할 수 있도록 크기를 변경하세요.
#     숫자로만 관리하던 가격(PRICE)을 모든 신규 강좌에 대해 기본값 10000원이 들어가도록 DEFAULT 속성을 설정하세요.
#
# -- 1) 열 추가
# ALTER TABLE COURSES
# ADD DIFFICULTY VARCHAR2(20);
#
# -- RATING_SCORE, RATING_COUNT 열 추가
# ALTER TABLE COURSES
# ADD (
#     RATING_SCORE NUMBER(3,1),
#     RATING_COUNT NUMBER
# );
#
# -- 2) 열 속성 수정
# ALTER TABLE COURSES
# MODIFY TITLE VARCHAR2(200);
#
# -- PRICE 기본값 10000 설정
# ALTER TABLE COURSES
# MODIFY (PRICE NUMBER(8,0) DEFAULT 10000);
#
# <html>
# 1. [실습] 3x2행열 테이블을 만들고, 그 안에 들어갈 이미지 4개(과일)을 다운로드 받은 후, 출력하세요..첫번째 행에서 과일을 이름 th로 출력.
# <table border="1">
#   <tr>
#     <th>사과&포도</th>
#     <th>바나나&오렌지</th>
#   </tr>
#
#   <tr>
#     <td><img src="apple.jpg" width="100"></td>
#     <td><img src="banana.jpg" width="100"></td>
#   </tr>
#
#   <tr>
#     <td><img src="grape.jpg" width="100"></td>
#     <td><img src="orange.jpg" width="100"></td>
#   </tr>
# </table>
#
# 2. [개념] a link 즉 하이퍼링크의 기본 개념과 핵심 태그 및 속성으로 예제 페이지로 설명하세요.
# <a href="https://www.naver.com" target="_blank" title="네이버 홈페이지">네이버 새 탭</a>
# a link에 핵심 태그/속성엔 이동할 주소를 나타내는 href, 링크를 어떤 방식으로 열지 격ㄹ정하는 target
# (예제에서 blank는 새탭으로 여는것), 링크의 설명을 나타내는 title이 있다.
#
# 3. [실습] ol li 태그와 a href 태그를 혼합하여 외부페이지(g마켓), 내부페이지(로그인페이지/상품페이지/관리자 페이지)로 이동하게 처리하세요.
# <ol>
#   <li><a href="https://www.gmarket.co.kr">G마켓</a></li>
#   <li><a href="login.html">로그인 페이지</a></li>
#   <li><a href="product.html">상품 페이지</a></li>
#   <li><a href="admin.html">관리자 페이지</a></li>
# </ol>
#
# 4. [실습] table과 img 태그에 link를 연동하여 네이버, 다음, 구글 portal 사이트로 이동하게 하세요..
# <table border="1">
#   <tr>
#     <td><a href="https://www.naver.com"><img src="naver.png" width="100"></a></td>
#     <td><a href="https://www.daum.net"><img src="daum.png" width="100"></a></td>
#     <td><a href="https://www.google.com"><img src="google.png" width="100"></a></td>
#   </tr>
# </table>
#
# 5. [개념] iframe의 기본 속성을 간단한 예제와 함께 설명해 보세요.
# <iframe src="https://www.naver.com" width="600" height="400" frameborder="0"></iframe>
# iframe의 기본 속성에는 src, width, height 등이 있다. src는 불러올 페이지의 주소이고, width/height는
# 가로와 세로 크기를 정할 때 사용하고, frameborder는 테두리 표시 여부를 결정할 때 사용한다.예제에서 0은 테두리 없음을 의미
#
# 6. [실습] 구글지도로 휴먼교육센터와 본인의 집을 url 주소로 복사한 후, 가로로 iframe을 설정하여 화면에 출력하세요.
# <div style="display:flex; gap:20px;">
#   <!-- 휴먼교육센터 -->
#   <iframe
#     src="https://maps.app.goo.gl/4sfHJsXNnTXW9KPC9"
#     width="400" height="300" style="border:0;">
#   </iframe>
#
#   <!-- 내 집 -->
#   <iframe
#     src="https://maps.app.goo.gl/71x6XpWqzYMP3tKEA"
#     width="400" height="300" style="border:0;">
#   </iframe>
# </div>

# %% [markdown]
# > 2단계

# %% [markdown]
# ORACLE: 데이터베이스 왕국의 기사 되기 ⚔️
# 문제 1: '영웅 관리소'에 새로운 능력 칸 추가하기!
# 당신은 'HERO_LIST' 테이블을 관리하는 기사입니다. 최근 영웅들에게 '마력(Mana Point)'이라는 새로운 능력이 생겨, 이를 기록할 공간이 필요해졌습니다.
#
# 미션: ALTER TABLE의 ADD 명령어를 사용하여 HERO_LIST 테이블에 **MANA_POINT**라는 이름의 숫자 타입(NUMBER) 컬럼을 추가하세요.
#
# ALTER TABLE HERO_LIST
# ADD MANA_POINT NUMBER;
#
#
# 문제 2: 왕국 서류의 오타 수정 작전!
# 왕국의 EMP01 테이블에 있는 ENAME(이름) 컬럼의 크기가 너무 작아 긴 이름을 가진 기사들의 이름이 잘리는 문제가 발생했습니다. 더 큰 공간으로 '리모델링'이 필요합니다.
#
# 미션: ALTER TABLE의 MODIFY 명령어를 사용하여 EMP01 테이블의 ENAME 컬럼의 데이터 타입을 VARCHAR2(50)으로 더 크게 변경하세요.
#
# ALTER TABLE EMP01
# MODIFY ENAME VARCHAR2(50);
#
#
# 문제 3: 헷갈리는 '보너스' 컬럼 이름 변경 후 삭제하기!
# EMP01 테이블의 SAL(월급) 컬럼 이름이 너무 딱딱해서 SALARY로 바꾸라는 왕의 명령이 떨어졌습니다. 며칠 뒤, 왕은 변심하여 SALARY 컬럼 자체가 필요 없으니 아예 없애라고 합니다.
#
# 미션:
#
# ALTER TABLE의 **RENAME COLUMN**을 사용해 EMP01 테이블의 SAL 컬럼을 **SALARY**로 변경하세요.
# ALTER TABLE EMP01
# RENAME COLUMN SAL TO SALARY;
#
# 다시 ALTER TABLE의 **DROP COLUMN**을 사용해 방금 이름을 바꾼 SALARY 컬럼을 완전히 삭제하세요.
# ALTER TABLE EMP01
# DROP COLUMN SALARY;
#
#
# 문제 4: 신입 기사 등록 실수 되돌리기!
# 당신은 신입 기사 '캡틴 코딩'의 정보를 EMP01 테이블에 등록하는 중입니다. 하지만 실수로 부서 번호를 잘못 입력했습니다! 이 실수가 영원히 기록되기 전에 되돌려야 합니다.
#
# 미션:
#
# INSERT 문으로 '캡틴 코딩'의 정보를 잘못된 부서 번호로 추가하세요.
#
# 실수를 깨닫고 ROLLBACK 명령어를 실행하여 INSERT 작업을 취소하세요.
#
# 다시 INSERT 문으로 '캡틴 코딩'의 정보를 올바른 부서 번호로 추가하세요.
#
# 마지막으로 **COMMIT**을 실행하여 영구적으로 저장하세요.
#
# INSERT INTO EMP01 (ENAME, DEPTNO) VALUES ('캡틴 코딩', 99);
# ROLLBACK;
#
# INSERT INTO EMP01 (ENAME, DEPTNO) VALUES ('캡틴 코딩', 10);
# COMMIT;
#
#
# 문제 5: 대규모 업데이트 중, '중간 저장'의 마법!
# 오늘은 왕국 기사들의 대규모 정보 업데이트 날! 당신의 임무는 3가지입니다.
#
# 모든 기사의 POINT를 500씩 올려주기
#
# 신규 기사 '닥터 디버그'를 추가하기
#
# 실수로 전설적인 영웅 '마스터 쿼리'의 정보를 삭제해버림
#
# 미션:
#
# 모든 기사의 POINT를 500 올리는 UPDATE 문을 실행하세요.
#
# SAVEPOINT sp1; 명령어로 현재까지의 작업을 중간 저장하세요.
#
# 신규 기사 '닥터 디버그'를 INSERT 하세요.
#
# '마스터 쿼리'의 정보를 DELETE 하세요 (실수 상황 연출).
#
# ROLLBACK TO sp1; 명령어로 '마스터 쿼리' 삭제와 '닥터 디버그' 추가를 모두 취소하고, 포인트만 올린 상태로 되돌아가세요!
#
# 마지막으로 COMMIT하여 포인트 인상분만 최종 저장하세요.
#
# UPDATE HERO_LIST
# SET POINT = POINT + 500;
# SAVEPOINT sp1;
#
# INSERT INTO HERO_LIST (HERO_NAME, POINT) VALUES ('닥터 디버그', 0);
#
# DELETE FROM HERO_LIST
# WHERE HERO_NAME = '마스터 쿼리';
#
# ROLLBACK TO sp1;
# COMMIT;
#
#
#
# ## HTML: 비밀 요원, Agent HTML의 첩보 작전
#
# ### 문제 1: 용의자 3명의 기본 프로필 만들기!
#
# 당신의 코드네임은 "Agent HTML". 첫 번째 임무는 이번 작전의 핵심 용의자 3명의 기본 프로필을 `<table>`을 이용해 만드는 것이다. 각 용의자의 얼굴 사진을 나란히 배치하여 한눈에 파악할 수 있도록 하라.
#
# * **미션:** `<table>`을 만들어, 첫 번째 줄(`<th>`)에는 용의자들의 코드네임인 **"Shadow", "Viper", "Ghost"**를 표시하라. 두 번째 줄(`<td>`)에는 각 코드네임 아래에 해당 용의자의 이미지 파일(`<img>`)을 배치하여 3칸짜리 프로필 보드를 완성하라. (이미지 크기는 가로 100px, 세로 100px로 통일)
#
# <table border="1">
#   <tr>
#     <th>Shadow</th>
#     <th>Viper</th>
#     <th>Ghost</th>
#   </tr>
#   <tr>
#     <td><img src="shadow.jpg" width="100" height="100"></td>
#     <td><img src="viper.jpg" width="100" height="100"></td>
#     <td><img src="ghost.jpg" width="100" height="100"></td>
#   </tr>
# </table>
#
#
# ---
#
# ### 문제 2: 프로필 사진에 비밀 정보 링크를 심어라!
#
# 기본 프로필이 완성되었다. 이제 각 용의자의 사진을 클릭하면, 그들에 대한 상세 정보 파일로 연결되는 비밀 링크를 심어야 한다. 정보는 내/외부 서버에 흩어져 있으니 정확히 연결해야 한다.
#
# * **미션:** 문제 1에서 만든 프로필 보드를 수정하라.
#     1.  **"Shadow"**의 이미지를 클릭하면, 외부 정보기관 사이트(**`https://www.naver.com`**)가 **새 탭**으로 열리도록 `<a>` 태그를 설정하라.
#     2.  **"Viper"**의 이미지를 클릭하면, 우리 기관 내부 파일(**`viper_info.html`**)이 **현재 탭**에서 열리도록 `<a>` 태그를 설정하라.
#
# ---
#
# ### 문제 3: 실시간 감시 대시보드 구축!
#
# "Viper"가 움직이기 시작했다! 그의 블로그와 우리 기관의 내부 지도를 동시에 감시할 수 있는 대시보드를 `<iframe>`을 이용해 즉시 구축하라.
#
# * **미션:** 하나의 HTML 파일 안에 `<iframe>` 두 개를 나란히 배치하라.
#     1.  **왼쪽 프레임 (너비 49%)**에는 Viper의 활동을 볼 수 있는 외부 사이트(**`https://ko.wikipedia.org/wiki/HTML`**)를 연결하라.
#     2.  **오른쪽 프레임 (너비 49%)**에는 작전 구역이 표시된 내부 지도 파일(**`map.html`**)을 연결하라.
#     3.  두 프레임 모두 높이는 `400px`, 테두리는 보이지 않게(`frameborder="0"`) 설정하여 전문가처럼 보이게 하라.
#
# ---
#
# ### 문제 4: 최첨단 스파이 장비 목록표 만들기!
#
# 정보부(Q)에서 새로운 스파이 장비 3종을 보급했다. 각 장비의 이름과 사용 설명서(매뉴얼)를 연결한 깔끔한 표를 만들어 동료 요원들에게 공유하라.
#
# * **미션:** `<table>`을 사용하여 '장비명'과 '매뉴얼' 두 개의 열을 만들어라.
#     1.  첫 번째 행에는 '레이저 시계'를 등록하고, '매뉴얼' 칸의 **텍스트 "보기"**를 클릭하면 내부 파일 **`watch_manual.html`**로 이동하도록 링크를 걸어라.
#     2.  두 번째 행에는 '만능 갈고리총'을 등록하고, '매뉴얼' 칸의 **텍스트 "보기"**를 클릭하면 외부 장비 사이트(**`https://www.youtube.com`**)가 **새 탭**으로 열리도록 링크를 걸어라.
#
# ---
#
# ### 문제 5: 최종 임무 보고서(Debriefing) 페이지 완성하기!
#
# 모든 작전이 종료되었다. 수집한 핵심 증거물과 당시의 위성 영상을 하나의 보고서 페이지에 종합하여 제출해야 한다. `<table>`로 레이아웃을 잡고, `<img>`, `<a>`, `<iframe>` 기술을 모두 활용하라.
#
# * **미션:** 2행 2열 구조의 `<table>` 레이아웃을 만들어 최종 보고서를 완성하라.
#     1.  **첫 번째 행**은 두 칸을 병합(`colspan="2"`)하여 **`<h2>최종 임무 보고서</h2>`** 제목을 중앙에 표시하라.
#     2.  **두 번째 행의 왼쪽 칸**에는 '핵심 증거물'이라는 소제목과 함께, **'top_secret.jpg' 이미지**를 넣어라. 이 이미지를 클릭하면 상세 증거 페이지(**`evidence.html`**)로 이동해야 한다.
#     3.  **두 번째 행의 오른쪽 칸**에는 '작전 당시 위성 영상'이라는 소제목과 함께, 당시 상황을 보여주는 `<iframe>`(**`https://www.google.com/maps/embed?`**...)을 삽입하라.

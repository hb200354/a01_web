# %% [markdown]
# Good morning QUIZ! 오늘도 좋은 하루입니다. 마음의 선택부터 하시죠 ^^
#
# ### 📝 객관식 문제 (4지선다형, 총 20문)
#
# **Oracle SQL (10문제)**
#
# 1.  **다음 중 `TO_NUMBER('7,777', '9,999')` 함수의 역할로 가장 올바른 것은?**<br>
#     A. 숫자 7777을 '7,777' 형식의 문자열로 변환한다.<br>
#     <u>B. 문자열 '7,777'을 숫자 데이터 7777로 변환하여 산술 연산이 가능하게 한다.</u><br>
#     C. 문자열에서 쉼표(,)를 제거하는 역할을 한다.<br>
#     D. 숫자를 지정된 형식(9,999)에 맞는지 검증하는 역할을 한다.<br>
#
# 2.  **문자열 '2025년 10월 26일'을 오라클 날짜 데이터로 변환하기 위한 `TO_DATE` 함수의 올바른 형식(format)은 무엇인가?**<br>
#     A. `'YYYY-MM-DD'`<br>
#     B. `'YYYY/MM/DD'`<br>
#     <u>C. `'YYYY"년"MM"월"DD"일"'`</u><br>
#     D. `'YYYY MM DD'`<br>
#
# 3.  **`SYSDATE + 1`이 의미하는 바로 가장 적절한 것은?**<br>
#     A. 현재 시간으로부터 1분 후<br>
#     B. 현재 시간으로부터 1시간 후<br>
#     <u>C. 오늘로부터 정확히 24시간 뒤의 날짜와 시간 (내일)</u><br>
#     D. 연도가 1년 증가한 날짜<br>
#
# 4.  **다음 중 오라클 그룹 함수가 아닌 것은?**<br>
#     A. `SUM()`<br>
#     B. `AVG()`<br>
#     <u>C. `FLOOR()`</u><br>
#     D. `COUNT()`<br>
#
# 5.  **`GROUP BY` 절에 대한 설명으로 가장 올바른 것은?**<br>
#     A. 테이블의 모든 행을 오름차순으로 정렬한다.<br>
#     <u>B. 특정 컬럼의 값을 기준으로 데이터를 작은 그룹으로 나누어 집계 함수를 적용하기 위해 사용한다.</u><br>
#     C. 그룹화된 결과에 대한 조건을 지정하며, `WHERE` 절보다 먼저 실행된다.<br>
#     D. 테이블에서 특정 조건을 만족하는 행만 선택한다.<br>
#
# 6.  **`WHERE` 절과 `HAVING` 절의 핵심적인 차이점은 무엇인가?**<br>
#     A. `WHERE`는 숫자, `HAVING`은 문자열 조건에만 사용된다.<br>
#     <u>B. `WHERE`는 그룹화 전 개별 행에 대한 조건, `HAVING`은 그룹화 후의 결과에 대한 조건이다.</u><br>
#     C. `HAVING` 절은 반드시 `GROUP BY` 절 앞에 와야 한다.<br>
#     D. 두 절은 기능적으로 완전히 동일하며 혼용해서 사용할 수 있다.<br>
#
# 7.  **`COUNT(*)`와 `COUNT(SAL)`의 차이점에 대한 설명으로 가장 적절한 것은?**<br>
#     <u>A. `COUNT(*)`는 모든 행의 개수를 세고, `COUNT(SAL)`은 급여(SAL)가 NULL이 아닌 행의 개수만 센다.</u><br>
#     B. `COUNT(*)`는 숫자 컬럼에만, `COUNT(SAL)`은 문자 컬럼에만 사용할 수 있다.<br>
#     C. 두 함수의 성능은 동일하지만 `COUNT(SAL)`이 표준적인 표현이다.<br>
#     D. `COUNT(*)`는 행의 개수, `COUNT(SAL)`은 급여의 합계를 계산한다.
#
# 8.  **입사일(HIREDATE)을 기준으로 '연도별' 사원 수를 계산하려고 할 때, `GROUP BY` 절에 사용해야 할 표현으로 가장 적절한 것은?**<br>
#     A. `GROUP BY HIREDATE`<br>
#     <u>B. `GROUP BY TO_CHAR(HIREDATE, 'YYYY')`</u><br>
#     C. `GROUP BY TO_CHAR(HIREDATE, 'MM')`<br>
#     D. `GROUP BY 'YYYY'`
#
# 9.  **각 부서(`DEPTNO`)의 급여 합계를 계산하는 SQL 문으로 올바른 것은?**<br>
#     A. `SELECT DEPTNO, SUM(SAL) FROM EMP;`<br>
#     B. `SELECT DEPTNO, SUM(SAL) FROM EMP GROUP BY DEPTNO;`<br>
#     C. `SELECT DEPTNO, SUM(SAL) FROM EMP HAVING SUM(SAL) > 0;`<br>
#     D. `SELECT DEPTNO, AVG(SAL) FROM EMP GROUP BY DEPTNO;`
#
# 10. **`FLOOR(TO_DATE('2026-01-01', 'YYYY-MM-DD') - SYSDATE)` 쿼리의 실행 결과는 무엇을 의미하는가?**<br>
#     A. 2026년 1월 1일까지 남은 시간을 초 단위로 계산한다.<br>
#     B. 2026년 1월 1일까지 남은 날짜 수를 소수점을 포함하여 정확하게 계산한다.<br>
#     C. 2026년 1월 1일까지 남은 날짜 수에서 소수점 이하를 버림(절삭)하여 일 단위로 표시한다.<br>
#     D. 2026년 1월 1일의 요일을 계산한다.
#
# **HTML (10문제)**
#
# 11. **사용자가 특정 날짜를 달력에서 직접 선택하게 하려면 `input` 태그의 `type` 속성값으로 무엇을 사용해야 하는가?**<br>
#     A. `datetime-local`<br>
#     B. `month`<br>
#     C. `time`<br>
#     D. `date`
#
# 12. **`<input type="number">` 태그에서 입력 가능한 최솟값을 10으로 지정하는 속성은 무엇인가?**<br>
#     A. `max="10"`<br>
#     B. `step="10"`<br>
#     C. `min="10"`<br>
#     D. `value="10"`
#
# 13. **정확한 숫자 입력보다 슬라이더를 이용해 대략적인 범위 내의 값을 선택하게 할 때 더 적합한 `input` 타입은?**<br>
#     A. `range`<br>
#     B. `number`<br>
#     C. `tel`<br>
#     D. `url`
#
# 14. **사용자가 여러 개의 파일을 한 번에 업로드할 수 있도록 하려면 `<input type="file">` 태그에 어떤 속성을 추가해야 하는가?**<br>
#     A. `accept="multiple"`<br>
#     B. `multiple="multiple"`<br>
#     C. `select="many"`<br>
#     D. `upload="all"`
#
# 15. **폼(form) 안에서 관련된 입력 요소들을 시각적으로 그룹화하고, 그룹의 제목을 붙일 때 사용하는 태그 조합으로 올바른 것은?**<br>
#     A. `<group>`과 `<caption>`<br>
#     B. `<div>`와 `<h1>`<br>
#     C. `<form>`과 `<legend>`<br>
#     D. `<fieldset>`과 `<legend>`
#
# 16. **`<input type="file" accept="image/*">` 속성의 역할은 무엇인가?**<br>
#     A. 파일 탐색기에서 이미지 파일만 보이도록 필터링한다.<br>
#     B. 모든 종류의 파일을 이미지로 변환하여 업로드한다.<br>
#     C. 파일 업로드 개수를 이미지 개수로 제한한다.<br>
#     D. 업로드된 파일의 미리보기를 이미지로 보여준다.
#
# 17. **`<input type="tel">`에 `pattern="[0-9]{3}-[0-9]{4}-[0-9]{4}"` 속성을 사용했을 때 기대할 수 있는 효과로 가장 적절한 것은?**<br>
#     A. 입력된 전화번호가 유효한 번호인지 통신사를 통해 확인한다.<br>
#     B. 자동으로 010-1234-5678 형식으로 하이픈(-)을 넣어준다.<br>
#     C. 사용자가 `000-0000-0000` 형식에 맞게 입력하도록 유도하고, 제출 시 해당 형식을 검증한다.<br>
#     D. 숫자 3개, 4개, 4개를 합산하여 결과를 보여준다.
#
# 18. **폼 제출(submit) 시, 특정 입력 필드가 반드시 채워져 있도록 강제하는 속성은 무엇인가?**<br>
#     A. `pattern`<br>
#     B. `placeholder`<br>
#     C. `required`<br>
#     D. `readonly`
#
# 19. **다음 중 날짜와 시간을 '한 번에' 입력받는 `input` 타입은 무엇인가?**<br>
#     A. `date`<br>
#     B. `time`<br>
#     C. `datetime-local`<br>
#     D. `week`
#
# 20. **`<input type="number" min="0" max="100" step="10">`에 대한 설명으로 틀린 것은?**<br>
#     A. 입력 가능한 최솟값은 0이다.<br>
#     B. 입력 가능한 최댓값은 100이다.<br>
#     C. 화살표를 클릭하면 값이 10씩 증가하거나 감소한다.<br>
#     D. 기본적으로 표시되는 값(value)은 10이다.
#
# -----
#
# ### ✍️ 주관식 문제 (총 5문)
#
# 1.  **[Oracle SQL]** `EMP` 테이블에서 1981년 2월 1일부터 1981년 6월 30일까지 입사한 사원들의 이름(`ENAME`)과 입사일(`HIREDATE`)을 조회하는 SQL 쿼리문을 `BETWEEN`과 `TO_DATE`를 사용하여 작성하시오.<br>
#
# 2.  **[Oracle SQL]** `EMP` 테이블에서 각 직책(`JOB`)별 평균 급여(`SAL`)를 계산하되, 평균 급여가 2500을 초과하는 직책과 해당 평균 급여만 출력하는 SQL 쿼리문을 `GROUP BY`와 `HAVING`을 사용하여 작성하시오.<br>
#
# 3.  **[HTML]** TV 볼륨을 조절하는 슬라이더를 만들려고 합니다. 이름(`name`)은 'vol'이고, 0부터 100까지 5 단위로 조절되며, 기본값은 50으로 설정된 `<input>` 태그를 작성하시오.<br>
#
# 4.  **[HTML]** 제공된 텍스트를 바탕으로, `<input type="number">`와 `<input type="range">`의 사용 목적(상황)의 주요 차이점을 간략히 서술하시오.<br>
#
# 5.  **[HTML]** 사용자가 자신의 프로필 사진을 업로드하는 입력 필드를 만들려고 합니다. 한 번에 하나의 이미지 파일(`.jpg`, `.png` 등)만 선택할 수 있도록 제한하는 `<input>` 태그를 작성하시오.<br>

# %% [markdown]
# ## 굿모닝 복습 퀴즈 (20문제)
#
# **1. 다음 중 HTML/CSS/JavaScript 개발을 위한 '메인 툴'로 언급된 것은 무엇인가요?**
#    1. Oracle SQL Developer
#    2. EditPlus
#    3. Total Commander
#    4. <span style="color:red">vscode</span>
#
# ---
#
# **2. Oracle 데이터베이스 설치 시 설정한 관리자 계정(system)의 비밀번호는 무엇이었나요?**
#    1. 1234
#    2. admin
#    3. <span style="color:red">1111</span>
#    4. tiger
#
# ---
#
# **3. Oracle 데이터베이스 리스너(listener)의 상태를 확인하는 명령어는 무엇인가요?**
#    1. `lsnrctl start`
#    2. `sqlplus system/1111`
#    3. <span style="color:red">lsnrctl status</span>
#    4. `show listener`
#
# ---
#
# **4. `scott.sql` 스크립트 파일을 실행하여 샘플 계정과 데이터를 생성하는 명령어는 무엇인가요?**
#    1. `run c:\Temp\scott.sql`
#    2. `execute c:\Temp\scott.sql`
#    3. <span style="color:red">@ c:\Temp\scott.sql</span>
#    4. `import c:\Temp\scott.sql`
#
# ---
#
# **5. 텍스트 편집 및 레거시(legacy) 프로그래밍 툴로 언급된 것은 무엇인가요?**
#    1. vscode
#    2. <span style="color:red">EditPlus</span>
#    3. Total Commander
#    4. Chrome
#
# ---
#
# **6. HTML5 문서임을 브라우저에 알리는 지시어는 무엇인가요?**
#    1. `<html>`
#    2. `<head>`
#    3. <span style="color:red">!DOCTYPE html</span>
#    4. `<meta charset="UTF-8">`
#
# ---
#
# **7. HTML 문서의 구조에서 실제 브라우저 화면에 표시되는 콘텐츠를 담는 태그는 무엇인가요?**
#    1. `<head>`
#    2. <span style="color:red">body</span>
#    3. `<html>`
#    4. `<title>`
#
# ---
#
# **8. HTML에서 가장 큰 글씨의 제목을 나타내는 태그는 무엇인가요?**
#    1. `<h6>`
#    2. <span style="color:red">h1</span>
#    3. `<head>`
#    4. `<title>`
#
# ---
#
# **9. <img> 태그에서 이미지 파일의 경로를 지정하는 속성은 무엇인가요?**
#    1. alt
#    2. title
#    3. href
#    4. <span style="color:red">src</span>
#
# ---
#
# **10. <img> 태그에서 이미지를 불러올 수 없을 때 대신 표시될 텍스트를 지정하는 속성은 무엇인가요?**<br>
#     1. src<br>
#     2. title<br>
#     3. <span style="color:red">alt</span><br>
#     4. name
#
# ---
#
# **11. HTML 태그에 마우스를 올렸을 때 나타나는 풍선 도움말(툴팁)을 설정하는 속성은 무엇인가요?**<br>
#     1. alt<br>
#     2. value<br>
#     3. hint<br>
#     4. <span style="color:red">title</span>
#
# ---
#
# **12. HTML 주석을 올바르게 작성한 것은 무엇인가요?**<br>
#     1. `// 이것은 주석입니다.`<br>
#     2. <span style="color:red">/* 이것은 주석입니다. */</span><br>
#     3. ``<br>
#     4. `# 이것은 주석입니다.`
#
# ---
#
# **13. SQL에서 테이블의 모든 열(column)을 선택할 때 사용하는 기호는 무엇인가요?**<br>
#     1. `@`<br>
#     2. `&`<br>
#     3. `%`<br>
#     4. <span style="color:red">*</span>
#
# ---
#
# **14. SQL의 SELECT 문에서 데이터를 가져올 테이블을 지정하는 키워드는 무엇인가요?**<br>
#     1. <span style="color:red">FROM</span><br>
#     2. `WHERE`<br>
#     3. `TABLE`<br>
#     4. `IN`
#
# ---
#
# **15. SQL에서 `EMP` 테이블의 `ENAME`과 `JOB` 열만 선택하는 올바른 구문은 무엇인가요?**<br>
#     1. `SELECT * FROM EMP;`<br>
#     2. <span style="color:red">SELECT ENAME, JOB FROM EMP;</span><br>
#     3. `SELECT ENAME AND JOB FROM EMP;`<br>
#     4. `SELECT (ENAME, JOB) FROM EMP;`
#
# ---
#
# **16. SQL에서 `SAL` 컬럼의 값을 100배하여 `SAL100`이라는 별칭(Alias)으로 출력하는 구문으로 틀린 것은 무엇인가요?**<br>
#     1. `SELECT SAL * 100 AS SAL100 FROM EMP;`<br>
#     2. `SELECT SAL * 100 SAL100 FROM EMP;`<br>
#     3. <span style="color:red">SELECT SAL * 100 = SAL100 FROM EMP;</span><br>
#     4. `SELECT SAL * 100 "SAL100" FROM EMP;`
#
# ---
#
# **17. SQL에서 문자열이나 컬럼 값을 연결할 때 사용하는 연산자는 무엇인가요?**<br>
#     1. `+`<br>
#     2. `&`<br>
#     3. <span style="color:red">||</span><br>
#     4. `.`
#
# ---
#
# **18. Oracle SQL에서 한 줄 주석을 나타내는 기호는 무엇인가요?**<br>
#     1. `//`<br>
#     2. `#`<br>
#     3. <span style="color:red">--</span><br>
#     4. `*`
#
# ---
#
# **19. 다음 중 시작 태그와 종료 태그가 쌍으로 존재하지 않는 태그는 무엇인가요? (내용 기반)**<br>
#     1. `<html>`<br>
#     2. `<h1>`<br>
#     3. <span style="color:red">br</span><br>
#     4. `<title>`
#
# ---
#
# **20. 'system' 관리자 계정으로 Oracle 데이터베이스에 접속하는 올바른 명령어 형식은 무엇인가요?**<br>
#     1. `sqlplus scott/tiger@localhost/xepdb1`<br>
#     2. `sqlplus system@localhost/xepdb1/1111`<br>
#     3. <span style="color:red">sqlplus system/1111@localhost/xepdb1</span><br>
#     4. `connect system/1111`
